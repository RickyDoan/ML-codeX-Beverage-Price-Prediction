# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.naive_bayes import GaussianNB

df = pd.read_csv('survey_results.csv')

# %%
print(df.shape)
df.head()
# Out:
# (30010, 17)
#   respondent_id  age gender   zone            occupation income_levels  \
# 0        R00001   30      M  Urban  Working Professional          <10L
# 1        R00002   46      F  Metro  Working Professional         > 35L
# 2        R00003   41      F  Rural  Working Professional         > 35L
# 3        R00004   33      F  Urban  Working Professional     16L - 25L
# 4        R00005   23      M  Metro               Student           NaN
#
#   consume_frequency(weekly) current_brand preferable_consumption_size  \
# 0                 3-4 times      Newcomer             Medium (500 ml)
# 1                 5-7 times   Established             Medium (500 ml)
# 2                 3-4 times      Newcomer             Medium (500 ml)
# 3                 5-7 times      Newcomer             Medium (500 ml)
# 4                 3-4 times   Established             Medium (500 ml)
#
#   awareness_of_other_brands reasons_for_choosing_brands flavor_preference  \
# 0                    0 to 1                       Price       Traditional
# 1                    2 to 4                     Quality            Exotic
# 2                    2 to 4                Availability       Traditional
# 3                    0 to 1            Brand Reputation            Exotic
# 4                    0 to 1                Availability       Traditional
#
#   purchase_channel packaging_preference                       health_concerns  \
# 0           Online               Simple  Medium (Moderately health-conscious)
# 1     Retail Store              Premium  Medium (Moderately health-conscious)
# 2     Retail Store              Premium  Medium (Moderately health-conscious)
# 3           Online         Eco-Friendly              Low (Not very concerned)
# 4           Online              Premium  Medium (Moderately health-conscious)
#
#   typical_consumption_situations price_range
# 0       Active (eg. Sports, gym)     100-150
# 1           Social (eg. Parties)     200-250
# 2       Active (eg. Sports, gym)     200-250
# 3       Active (eg. Sports, gym)     150-200
# 4       Active (eg. Sports, gym)      50-100

# %% [markdown]
# <h1 align='center'>Cleaning Data<h1>

# %% [markdown]
# ### 1 / Check duplicated

# %%
# 1 / Check duplicated
df.duplicated().sum()
# Out:
# np.int64(10)

# %%
df.drop_duplicates(keep='first', inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (30000, 17)

# %% [markdown]
# ### 2/  Check outliers from age column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30000 entries, 0 to 30009
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   respondent_id                   30000 non-null  object
#  1   age                             30000 non-null  int64
#  2   gender                          30000 non-null  object
#  3   zone                            30000 non-null  object
#  4   occupation                      30000 non-null  object
#  5   income_levels                   21939 non-null  object
#  6   consume_frequency(weekly)       29992 non-null  object
#  7   current_brand                   30000 non-null  object
#  8   preferable_consumption_size     30000 non-null  object
#  9   awareness_of_other_brands       30000 non-null  object
#  10  reasons_for_choosing_brands     30000 non-null  object
#  11  flavor_preference               30000 non-null  object
#  12  purchase_channel                29990 non-null  object
#  13  packaging_preference            30000 non-null  object
#  14  health_concerns                 30000 non-null  object
#  15  typical_consumption_situations  30000 non-null  object
#  16  price_range                     30000 non-null  object
# dtypes: int64(1), object(16)
# memory usage: 4.1+ MB

# %%
df.describe()
# Out:
#                 age
# count  30000.000000
# mean      33.048167
# std       13.438904
# min       18.000000
# 25%       23.000000
# 50%       31.000000
# 75%       40.000000
# max      604.000000

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, y='age')
plt.title('Boxplot of Age')
plt.xlabel('Age')
plt.show()

# %%
print(df[df['age'] > 100].shape)
df[df['age'] > 100]
# Out:
# (9, 17)
#       respondent_id  age gender        zone            occupation  \
# 3099         R03098  453      M       Metro  Working Professional
# 6262         R06260  428      M       Urban          Entrepreneur
# 12403        R12398  604      M       Metro               Retired
# 22549        R22542  457      M       Metro  Working Professional
# 22918        R22911  267      F       Metro  Working Professional
# 24958        R24950  285      M  Semi-Urban  Working Professional
# 24960        R24952  192      F       Urban               Student
# 25105        R25096  203      M       Metro  Working Professional
# 28770        R28761  428      F       Rural  Working Professional
#
#       income_levels consume_frequency(weekly) current_brand  \
# 3099      26L - 35L                 3-4 times   Established
# 6262      16L - 25L                 5-7 times   Established
# 12403          <10L                 0-2 times      Newcomer
# 22549     16L - 25L                 3-4 times      Newcomer
# 22918     16L - 25L                 3-4 times   Established
# 24958         > 35L                 0-2 times      Newcomer
# 24960           NaN                 3-4 times      Newcomer
# 25105     16L - 25L                 0-2 times   Established
# 28770     26L - 35L                 0-2 times   Established
#
#       preferable_consumption_size awareness_of_other_brands  \
# 3099              Medium (500 ml)                    2 to 4
# 6262                  Large (1 L)                   above 4
# 12403              Small (250 ml)                    2 to 4
# 22549              Small (250 ml)                    2 to 4
# 22918             Medium (500 ml)                   above 4
# 24958              Small (250 ml)                    2 to 4
# 24960             Medium (500 ml)                    0 to 1
# 25105              Small (250 ml)                    2 to 4
# 28770              Small (250 ml)                    2 to 4
#
#       reasons_for_choosing_brands flavor_preference purchase_channel  \
# 3099             Brand Reputation       Traditional     Retail Store
# 6262                      Quality            Exotic           Online
# 12403                Availability       Traditional           Online
# 22549                       Price       Traditional           Online
# 22918            Brand Reputation            Exotic           Online
# 24958                       Price       Traditional           Online
# 24960                       Price       Traditional           Online
# 25105            Brand Reputation            Exotic     Retail Store
# 28770            Brand Reputation            Exotic           Online
#
#       packaging_preference                       health_concerns  \
# 3099               Premium  Medium (Moderately health-conscious)
# 6262                Simple          High (Very health-conscious)
# 12403               Simple  Medium (Moderately health-conscious)
# 22549              Premium          High (Very health-conscious)
# 22918         Eco-Friendly              Low (Not very concerned)
# 24958               Simple  Medium (Moderately health-conscious)
# 24960               Simple              Low (Not very concerned)
# 25105              Premium          High (Very health-conscious)
# 28770               Simple  Medium (Moderately health-conscious)
#
#       typical_consumption_situations price_range
# 3099            Social (eg. Parties)     200-250
# 6262            Social (eg. Parties)     200-250
# 12403           Casual (eg. At home)     100-150
# 22549           Casual (eg. At home)     200-250
# 22918       Active (eg. Sports, gym)     150-200
# 24958       Active (eg. Sports, gym)     150-200
# 24960       Active (eg. Sports, gym)      50-100
# 25105       Active (eg. Sports, gym)     150-200
# 28770           Casual (eg. At home)     150-200

# %%
df[df['age'] > 100]['age'].max()
# Out:
# 604

# %%
# Drop age which greater than 100
df = df[df['age'] < 100]

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, y='age')
plt.title('Boxplot of Age')
plt.xlabel('Age')
plt.show()

# %%
df.shape
# Out:
# (29991, 17)

# %% [markdown]
# ### 3 / How many null values are present in the consume_frequency(weekly) column? What is the mode value used to fill these null values?

# %%
df.head(3)
# Out:
#   respondent_id  age gender   zone            occupation income_levels  \
# 0        R00001   30      M  Urban  Working Professional          <10L
# 1        R00002   46      F  Metro  Working Professional         > 35L
# 2        R00003   41      F  Rural  Working Professional         > 35L
#
#   consume_frequency(weekly) current_brand preferable_consumption_size  \
# 0                 3-4 times      Newcomer             Medium (500 ml)
# 1                 5-7 times   Established             Medium (500 ml)
# 2                 3-4 times      Newcomer             Medium (500 ml)
#
#   awareness_of_other_brands reasons_for_choosing_brands flavor_preference  \
# 0                    0 to 1                       Price       Traditional
# 1                    2 to 4                     Quality            Exotic
# 2                    2 to 4                Availability       Traditional
#
#   purchase_channel packaging_preference                       health_concerns  \
# 0           Online               Simple  Medium (Moderately health-conscious)
# 1     Retail Store              Premium  Medium (Moderately health-conscious)
# 2     Retail Store              Premium  Medium (Moderately health-conscious)
#
#   typical_consumption_situations price_range
# 0       Active (eg. Sports, gym)     100-150
# 1           Social (eg. Parties)     200-250
# 2       Active (eg. Sports, gym)     200-250

# %%
# Null value in consume_frequency
df['consume_frequency(weekly)'].isna().sum()
# Out:
# np.int64(8)

# %%
df['consume_frequency(weekly)'].value_counts()
# Out:
# consume_frequency(weekly)
# 3-4 times    11786
# 5-7 times     9774
# 0-2 times     8423
# Name: count, dtype: int64

# %%
df['consume_frequency(weekly)'].mode()
# Out:
# 0    3-4 times
# Name: consume_frequency(weekly), dtype: object

# %% [markdown]
# * We will use mode 3-4 times to fill N/A values for consume_frequency

# %%
df['consume_frequency(weekly)']=df['consume_frequency(weekly)'].fillna('3-4 times')

# %%
df['consume_frequency(weekly)'].value_counts()
# Out:
# consume_frequency(weekly)
# 3-4 times    11794
# 5-7 times     9774
# 0-2 times     8423
# Name: count, dtype: int64

# %%
df['consume_frequency(weekly)'].isna().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (29991, 17)

# %%
df.isnull().sum()
# Out:
# respondent_id                        0
# age                                  0
# gender                               0
# zone                                 0
# occupation                           0
# income_levels                     8060
# consume_frequency(weekly)            0
# current_brand                        0
# preferable_consumption_size          0
# awareness_of_other_brands            0
# reasons_for_choosing_brands          0
# flavor_preference                    0
# purchase_channel                    10
# packaging_preference                 0
# health_concerns                      0
# typical_consumption_situations       0
# price_range                          0
# dtype: int64

# %%
# Check N/A income_levels

# %%
df[df['income_levels'].isna()]
# Out:
#       respondent_id  age gender        zone occupation income_levels  \
# 4            R00005   23      M       Metro    Student           NaN
# 5            R00006   22      F       Urban    Student           NaN
# 11           R00012   23      F       Urban    Student           NaN
# 14           R00015   22      M       Metro    Student           NaN
# 20           R00021   23      M  Semi-Urban    Student           NaN
# ...             ...  ...    ...         ...        ...           ...
# 29995        R29986   24      F       Metro    Student           NaN
# 29996        R29987   22      M       Urban    Student           NaN
# 29999        R29990   23      F       Metro    Student           NaN
# 30002        R29993   18      M       Metro    Student           NaN
# 30009        R30000   26      M       Metro    Student           NaN
#
#       consume_frequency(weekly) current_brand preferable_consumption_size  \
# 4                     3-4 times   Established             Medium (500 ml)
# 5                     5-7 times   Established                 Large (1 L)
# 11                    0-2 times   Established              Small (250 ml)
# 14                    3-4 times   Established              Small (250 ml)
# 20                    3-4 times      Newcomer                 Large (1 L)
# ...                         ...           ...                         ...
# 29995                 5-7 times      Newcomer              Small (250 ml)
# 29996                 0-2 times   Established              Small (250 ml)
# 29999                 3-4 times   Established              Small (250 ml)
# 30002                 0-2 times   Established             Medium (500 ml)
# 30009                 5-7 times      Newcomer             Medium (500 ml)
#
#       awareness_of_other_brands reasons_for_choosing_brands flavor_preference  \
# 4                        0 to 1                Availability       Traditional
# 5                        2 to 4                       Price       Traditional
# 11                       0 to 1                       Price            Exotic
# 14                       0 to 1                       Price       Traditional
# 20                       0 to 1                Availability       Traditional
# ...                         ...                         ...               ...
# 29995                    0 to 1                       Price       Traditional
# 29996                    0 to 1                       Price            Exotic
# 29999                    2 to 4                       Price            Exotic
# 30002                    2 to 4                Availability            Exotic
# 30009                   above 4                       Price       Traditional
#
#       purchase_channel packaging_preference  \
# 4               Online              Premium
# 5               Online               Simple
# 11        Retail Store              Premium
# 14        Retail Store               Simple
# 20        Retail Store              Premium
# ...                ...                  ...
# 29995           Online              Premium
# 29996           Online              Premium
# 29999           Online               Simple
# 30002           Online              Premium
# 30009     Retail Store               Simple
#
#                             health_concerns typical_consumption_situations  \
# 4      Medium (Moderately health-conscious)       Active (eg. Sports, gym)
# 5                  Low (Not very concerned)       Active (eg. Sports, gym)
# 11                 Low (Not very concerned)           Social (eg. Parties)
# 14     Medium (Moderately health-conscious)       Active (eg. Sports, gym)
# 20                 Low (Not very concerned)       Active (eg. Sports, gym)
# ...                                     ...                            ...
# 29995              Low (Not very concerned)           Social (eg. Parties)
# 29996              Low (Not very concerned)           Social (eg. Parties)
# 29999  Medium (Moderately health-conscious)       Active (eg. Sports, gym)
# 30002              Low (Not very concerned)           Social (eg. Parties)
# 30009          High (Very health-conscious)           Social (eg. Parties)
#
#       price_range
# 4          50-100
# 5         100-150
# 11         50-100
# 14        100-150
# 20         50-100
# ...           ...
# 29995     100-150
# 29996      50-100
# 29999     100-150
# 30002     100-150
# 30009     150-200
#
# [8060 rows x 17 columns]

# %%
df['income_levels'].value_counts()
# Out:
# income_levels
# 16L - 25L    5897
# 10L - 15L    5251
# <10L         4661
# 26L - 35L    3872
# > 35L        2250
# Name: count, dtype: int64

# %%
df['income_levels'].fillna('Not Reported', inplace=True)
# Out:
# /var/folders/q3/xgl4pwjd7lbg8skj81tsl0xr0000gn/T/ipykernel_67704/1816725272.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['income_levels'].fillna('Not Reported', inplace=True)

# %%
df.isnull().sum()
# Out:
# respondent_id                      0
# age                                0
# gender                             0
# zone                               0
# occupation                         0
# income_levels                      0
# consume_frequency(weekly)          0
# current_brand                      0
# preferable_consumption_size        0
# awareness_of_other_brands          0
# reasons_for_choosing_brands        0
# flavor_preference                  0
# purchase_channel                  10
# packaging_preference               0
# health_concerns                    0
# typical_consumption_situations     0
# price_range                        0
# dtype: int64

# %%
#Check purchase_channel
df['purchase_channel'].value_counts()
# Out:
# purchase_channel
# Online          16562
# Retail Store    13419
# Name: count, dtype: int64

# %%
df['purchase_channel'].mode()
# Out:
# 0    Online
# Name: purchase_channel, dtype: object

# %%
df['purchase_channel'] =df['purchase_channel'].fillna('Online')

# %%
df.isnull().sum()
# Out:
# respondent_id                     0
# age                               0
# gender                            0
# zone                              0
# occupation                        0
# income_levels                     0
# consume_frequency(weekly)         0
# current_brand                     0
# preferable_consumption_size       0
# awareness_of_other_brands         0
# reasons_for_choosing_brands       0
# flavor_preference                 0
# purchase_channel                  0
# packaging_preference              0
# health_concerns                   0
# typical_consumption_situations    0
# price_range                       0
# dtype: int64

# %%
df.shape
# Out:
# (29991, 17)

# %% [markdown]
# ### 4 / Correct spelling

# %%
df.columns
# Out:
# Index(['respondent_id', 'age', 'gender', 'zone', 'occupation', 'income_levels',
#        'consume_frequency(weekly)', 'current_brand',
#        'preferable_consumption_size', 'awareness_of_other_brands',
#        'reasons_for_choosing_brands', 'flavor_preference', 'purchase_channel',
#        'packaging_preference', 'health_concerns',
#        'typical_consumption_situations', 'price_range'],
#       dtype='object')

# %%
for col in df.select_dtypes('object').columns:
    print(f"{col} --> {df[col].unique()}")
# Out:
# respondent_id --> ['R00001' 'R00002' 'R00003' ... 'R29998' 'R29999' 'R30000']
# gender --> ['M' 'F']
# zone --> ['Urban' 'Metro' 'Rural' 'Semi-Urban' 'Metor' 'urbna']
# occupation --> ['Working Professional' 'Student' 'Entrepreneur' 'Retired']
# income_levels --> ['<10L' '> 35L' '16L - 25L' 'Not Reported' '10L - 15L' '26L - 35L']
# consume_frequency(weekly) --> ['3-4 times' '5-7 times' '0-2 times']
# current_brand --> ['Newcomer' 'Established' 'newcomer' 'Establishd']
# preferable_consumption_size --> ['Medium (500 ml)' 'Large (1 L)' 'Small (250 ml)']
# awareness_of_other_brands --> ['0 to 1' '2 to 4' 'above 4']
# reasons_for_choosing_brands --> ['Price' 'Quality' 'Availability' 'Brand Reputation']
# flavor_preference --> ['Traditional' 'Exotic']
# purchase_channel --> ['Online' 'Retail Store']
# packaging_preference --> ['Simple' 'Premium' 'Eco-Friendly']
# health_concerns --> ['Medium (Moderately health-conscious)' 'Low (Not very concerned)'
#  'High (Very health-conscious)']
# typical_consumption_situations --> ['Active (eg. Sports, gym)' 'Social (eg. Parties)' 'Casual (eg. At home)']
# price_range --> ['100-150' '200-250' '150-200' '50-100']

# %%
df['zone'] = df['zone'].replace('urbna', 'Urban')
df['zone'] = df['zone'].replace('Metor', 'Metro')
df['current_brand'] = df['current_brand'].replace('Establishd', 'Established')
df['current_brand'] = df['current_brand'].replace('newcomer', 'Newcomer')

# %%
df['current_brand'].unique()
# Out:
# array(['Newcomer', 'Established'], dtype=object)

# %%
print(df[df['zone'] == 'Metor'].shape)
df[df['zone'] == 'Metor']
# Out:
# (0, 17)
# Empty DataFrame
# Columns: [respondent_id, age, gender, zone, occupation, income_levels, consume_frequency(weekly), current_brand, preferable_consumption_size, awareness_of_other_brands, reasons_for_choosing_brands, flavor_preference, purchase_channel, packaging_preference, health_concerns, typical_consumption_situations, price_range]
# Index: []

# %%
df['zone'] = df['zone'].replace('Metor', 'Metro')

# %%
df['zone'].unique()
# Out:
# array(['Urban', 'Metro', 'Rural', 'Semi-Urban'], dtype=object)

# %% [markdown]
# <h1 align = 'center'>Feature Engineering<h1>

# %% [markdown]
# * Step 1:
# * Categorize Age into Age Groups
# * Objective: Create a new column `age_group` by categorizing the existing `age`
# column into specific age ranges.
# * ● Categorize ages into the following groups:
# * ○ 18-25 ○ 26-35 ○ 36-45 ○ 46-55 ○ 56-70 ○ 70+
# * ● Ensure that each age in the dataset is mapped to one of these age groups.
# * ● After that, remove the original `age` column from the dataset.

# %%
df.head()
# Out:
#   respondent_id  age gender   zone            occupation income_levels  \
# 0        R00001   30      M  Urban  Working Professional          <10L
# 1        R00002   46      F  Metro  Working Professional         > 35L
# 2        R00003   41      F  Rural  Working Professional         > 35L
# 3        R00004   33      F  Urban  Working Professional     16L - 25L
# 4        R00005   23      M  Metro               Student  Not Reported
#
#   consume_frequency(weekly) current_brand preferable_consumption_size  \
# 0                 3-4 times      Newcomer             Medium (500 ml)
# 1                 5-7 times   Established             Medium (500 ml)
# 2                 3-4 times      Newcomer             Medium (500 ml)
# 3                 5-7 times      Newcomer             Medium (500 ml)
# 4                 3-4 times   Established             Medium (500 ml)
#
#   awareness_of_other_brands reasons_for_choosing_brands flavor_preference  \
# 0                    0 to 1                       Price       Traditional
# 1                    2 to 4                     Quality            Exotic
# 2                    2 to 4                Availability       Traditional
# 3                    0 to 1            Brand Reputation            Exotic
# 4                    0 to 1                Availability       Traditional
#
#   purchase_channel packaging_preference                       health_concerns  \
# 0           Online               Simple  Medium (Moderately health-conscious)
# 1     Retail Store              Premium  Medium (Moderately health-conscious)
# 2     Retail Store              Premium  Medium (Moderately health-conscious)
# 3           Online         Eco-Friendly              Low (Not very concerned)
# 4           Online              Premium  Medium (Moderately health-conscious)
#
#   typical_consumption_situations price_range
# 0       Active (eg. Sports, gym)     100-150
# 1           Social (eg. Parties)     200-250
# 2       Active (eg. Sports, gym)     200-250
# 3       Active (eg. Sports, gym)     150-200
# 4       Active (eg. Sports, gym)      50-100

# %%
def categorize_age_group(age):
    if 18 <= age <= 25:
        return '18-25'
    elif 26 <= age <= 35:
        return '26-35'
    elif 36 <= age <= 45:
        return '36-45'
    elif 46 <= age <= 55:
        return '46-55'
    elif 56 <= age <= 70:
        return '56-70'
    elif age > 70:
        return '70+'
    else:
        return None

# %%
df['age_group'] = df['age'].apply(categorize_age_group)
df.drop('age', axis=1, inplace=True)
df.head()
# Out:
#   respondent_id gender   zone            occupation income_levels  \
# 0        R00001      M  Urban  Working Professional          <10L
# 1        R00002      F  Metro  Working Professional         > 35L
# 2        R00003      F  Rural  Working Professional         > 35L
# 3        R00004      F  Urban  Working Professional     16L - 25L
# 4        R00005      M  Metro               Student  Not Reported
#
#   consume_frequency(weekly) current_brand preferable_consumption_size  \
# 0                 3-4 times      Newcomer             Medium (500 ml)
# 1                 5-7 times   Established             Medium (500 ml)
# 2                 3-4 times      Newcomer             Medium (500 ml)
# 3                 5-7 times      Newcomer             Medium (500 ml)
# 4                 3-4 times   Established             Medium (500 ml)
#
#   awareness_of_other_brands reasons_for_choosing_brands flavor_preference  \
# 0                    0 to 1                       Price       Traditional
# 1                    2 to 4                     Quality            Exotic
# 2                    2 to 4                Availability       Traditional
# 3                    0 to 1            Brand Reputation            Exotic
# 4                    0 to 1                Availability       Traditional
#
#   purchase_channel packaging_preference                       health_concerns  \
# 0           Online               Simple  Medium (Moderately health-conscious)
# 1     Retail Store              Premium  Medium (Moderately health-conscious)
# 2     Retail Store              Premium  Medium (Moderately health-conscious)
# 3           Online         Eco-Friendly              Low (Not very concerned)
# 4           Online              Premium  Medium (Moderately health-conscious)
#
#   typical_consumption_situations price_range age_group
# 0       Active (eg. Sports, gym)     100-150     26-35
# 1           Social (eg. Parties)     200-250     46-55
# 2       Active (eg. Sports, gym)     200-250     36-45
# 3       Active (eg. Sports, gym)     150-200     26-35
# 4       Active (eg. Sports, gym)      50-100     18-25

# %%
# Step 2: Create `cf_ab_score` (Consume Frequency and Awareness Brand Score)
# Objective: Create a new column `cf_ab_score` by combining the information from `consume_frequency(weekly)` and `awareness_of_other_brands` columns.
# ● Use the following mappings for consume_frequency(weekly):
# ○ "0-2 times" → 1
# ○ "3-4 times" → 2
# ○ "5-7 times" → 3
# ● Use the following mappings for awareness_of_other_brands:
# ○ "0to1"→1
# ○ "2to4"→2
# ○ "above 4" → 3
# ● Calculate cf_ab_score using the following formula:
# cf_ab_score = (consume_frequency) / (consume_frequency + awareness_of_other_brands)

# %%
df['consume_frequency(weekly)'].unique()
# Out:
# array(['3-4 times', '5-7 times', '0-2 times'], dtype=object)

# %%
df['awareness_of_other_brands'].unique()
# Out:
# array(['0 to 1', '2 to 4', 'above 4'], dtype=object)

# %%
df['consume_frequency(weekly)'] = df['consume_frequency(weekly)'].map({'0-2 times': 1, '3-4 times': 2, '5-7 times': 3})
df['awareness_of_other_brands'] = df['awareness_of_other_brands'].map({'0 to 1' : 1, '2 to 4' : 2, 'above 4' : 3})
df.head()
# Out:
#   respondent_id gender   zone            occupation income_levels  \
# 0        R00001      M  Urban  Working Professional          <10L
# 1        R00002      F  Metro  Working Professional         > 35L
# 2        R00003      F  Rural  Working Professional         > 35L
# 3        R00004      F  Urban  Working Professional     16L - 25L
# 4        R00005      M  Metro               Student  Not Reported
#
#    consume_frequency(weekly) current_brand preferable_consumption_size  \
# 0                          2      Newcomer             Medium (500 ml)
# 1                          3   Established             Medium (500 ml)
# 2                          2      Newcomer             Medium (500 ml)
# 3                          3      Newcomer             Medium (500 ml)
# 4                          2   Established             Medium (500 ml)
#
#    awareness_of_other_brands reasons_for_choosing_brands flavor_preference  \
# 0                          1                       Price       Traditional
# 1                          2                     Quality            Exotic
# 2                          2                Availability       Traditional
# 3                          1            Brand Reputation            Exotic
# 4                          1                Availability       Traditional
#
#   purchase_channel packaging_preference                       health_concerns  \
# 0           Online               Simple  Medium (Moderately health-conscious)
# 1     Retail Store              Premium  Medium (Moderately health-conscious)
# 2     Retail Store              Premium  Medium (Moderately health-conscious)
# 3           Online         Eco-Friendly              Low (Not very concerned)
# 4           Online              Premium  Medium (Moderately health-conscious)
#
#   typical_consumption_situations price_range age_group
# 0       Active (eg. Sports, gym)     100-150     26-35
# 1           Social (eg. Parties)     200-250     46-55
# 2       Active (eg. Sports, gym)     200-250     36-45
# 3       Active (eg. Sports, gym)     150-200     26-35
# 4       Active (eg. Sports, gym)      50-100     18-25

# %%
df['cf_ab_score'] = (df['consume_frequency(weekly)'] / (df['consume_frequency(weekly)'] + df['awareness_of_other_brands'])).round(2)
df.head()
# Out:
#   respondent_id gender   zone            occupation income_levels  \
# 0        R00001      M  Urban  Working Professional          <10L
# 1        R00002      F  Metro  Working Professional         > 35L
# 2        R00003      F  Rural  Working Professional         > 35L
# 3        R00004      F  Urban  Working Professional     16L - 25L
# 4        R00005      M  Metro               Student  Not Reported
#
#    consume_frequency(weekly) current_brand preferable_consumption_size  \
# 0                          2      Newcomer             Medium (500 ml)
# 1                          3   Established             Medium (500 ml)
# 2                          2      Newcomer             Medium (500 ml)
# 3                          3      Newcomer             Medium (500 ml)
# 4                          2   Established             Medium (500 ml)
#
#    awareness_of_other_brands reasons_for_choosing_brands flavor_preference  \
# 0                          1                       Price       Traditional
# 1                          2                     Quality            Exotic
# 2                          2                Availability       Traditional
# 3                          1            Brand Reputation            Exotic
# 4                          1                Availability       Traditional
#
#   purchase_channel packaging_preference                       health_concerns  \
# 0           Online               Simple  Medium (Moderately health-conscious)
# 1     Retail Store              Premium  Medium (Moderately health-conscious)
# 2     Retail Store              Premium  Medium (Moderately health-conscious)
# 3           Online         Eco-Friendly              Low (Not very concerned)
# 4           Online              Premium  Medium (Moderately health-conscious)
#
#   typical_consumption_situations price_range age_group  cf_ab_score
# 0       Active (eg. Sports, gym)     100-150     26-35         0.67
# 1           Social (eg. Parties)     200-250     46-55         0.60
# 2       Active (eg. Sports, gym)     200-250     36-45         0.50
# 3       Active (eg. Sports, gym)     150-200     26-35         0.75
# 4       Active (eg. Sports, gym)      50-100     18-25         0.67

# %%
df['cf_ab_score'].max()
# Out:
# 0.75

# %%
# Step 3: Create Zone Affluence Score (ZAS)
# Objective: Calculate the `zas_score` using a combination of the `zone` and
# `income_levels` columns.
# ● Use the following mappings for the zone column:
# ○ "Urban" → 3
# ○ "Metro" → 4
# ○ "Rural" → 1
# ○ "Semi-Urban" → 2
# ● Use the following mappings for the income_levels column:
# ○ "<10L" → 1
# ○ "10L-15L"→2
# ○ "16L-25L"→3
# ○ "26L-35L"→4
# ○ ">35L"→5
# ○ "Not Reported" → 0
# ● Calculate the zas_score using the following formula:
# zas_score = zone_score * income_score

# %%
df['zone'].unique()
# Out:
# array(['Urban', 'Metro', 'Rural', 'Semi-Urban'], dtype=object)

# %%
df['income_levels'].unique()
# Out:
# array(['<10L', '> 35L', '16L - 25L', 'Not Reported', '10L - 15L',
#        '26L - 35L'], dtype=object)

# %%
def strip_income_leve(text):
    return text.replace(' ', '')

strip_income_leve('> 35L')
# Out:
# '>35L'

# %%
df['income_levels'] = df['income_levels'].apply(strip_income_leve)

# %%
df['income_levels'].unique()
# Out:
# array(['<10L', '>35L', '16L-25L', 'NotReported', '10L-15L', '26L-35L'],
#       dtype=object)

# %%
df['zone'] = df['zone'].map({"Rural" :1, "Urban" :3, "Semi-Urban" :2, "Metro" :4})
df['income_levels'] = df['income_levels'].map({"<10L": 1, "10L-15L":2, "16L-25L":3, "26L-35L":4, ">35L":5, "NotReported":0})
df['zas_score'] = df['zone'] * df['income_levels']
df.head()
# Out:
#   respondent_id gender  zone            occupation  income_levels  \
# 0        R00001      M     3  Working Professional              1
# 1        R00002      F     4  Working Professional              5
# 2        R00003      F     1  Working Professional              5
# 3        R00004      F     3  Working Professional              3
# 4        R00005      M     4               Student              0
#
#    consume_frequency(weekly) current_brand preferable_consumption_size  \
# 0                          2      Newcomer             Medium (500 ml)
# 1                          3   Established             Medium (500 ml)
# 2                          2      Newcomer             Medium (500 ml)
# 3                          3      Newcomer             Medium (500 ml)
# 4                          2   Established             Medium (500 ml)
#
#    awareness_of_other_brands reasons_for_choosing_brands flavor_preference  \
# 0                          1                       Price       Traditional
# 1                          2                     Quality            Exotic
# 2                          2                Availability       Traditional
# 3                          1            Brand Reputation            Exotic
# 4                          1                Availability       Traditional
#
#   purchase_channel packaging_preference                       health_concerns  \
# 0           Online               Simple  Medium (Moderately health-conscious)
# 1     Retail Store              Premium  Medium (Moderately health-conscious)
# 2     Retail Store              Premium  Medium (Moderately health-conscious)
# 3           Online         Eco-Friendly              Low (Not very concerned)
# 4           Online              Premium  Medium (Moderately health-conscious)
#
#   typical_consumption_situations price_range age_group  cf_ab_score  zas_score
# 0       Active (eg. Sports, gym)     100-150     26-35         0.67          3
# 1           Social (eg. Parties)     200-250     46-55         0.60         20
# 2       Active (eg. Sports, gym)     200-250     36-45         0.50          5
# 3       Active (eg. Sports, gym)     150-200     26-35         0.75          9
# 4       Active (eg. Sports, gym)      50-100     18-25         0.67          0

# %%
df['zas_score'].nunique()
# Out:
# 14

# %%
# Step 4: Brand Switching Indicator (BSI)
# Objective: Create a binary indicator column `bsi` that identifies if a respondent is likely to switch brands.
# ● Check if the respondent’s current_brand is not "Established".
# ● Also check if the reasons_for_choosing_brands are either "Price" or
# "Quality".
# ● If both conditions are true, assign a value of 1 to indicate potential for brand
# switching. Otherwise, assign 0.

# %%
df['bsi'] = ((df['current_brand'] != 'Established') & (df['reasons_for_choosing_brands'].isin(['Price', 'Quality']))).astype(int)
df.sample(25)
# Out:
#       respondent_id gender  zone            occupation  income_levels  \
# 15031        R15026      F     4               Student              0
# 20349        R20343      F     3  Working Professional              3
# 9127         R09123      F     2  Working Professional              4
# 29438        R29429      F     3  Working Professional              1
# 15594        R15589      M     3          Entrepreneur              1
# 27106        R27097      M     4  Working Professional              5
# 22105        R22099      M     1  Working Professional              2
# 21288        R21282      M     2               Student              0
# 1417         R01418      F     2  Working Professional              2
# 8013         R08010      M     2  Working Professional              3
# 22676        R22669      M     4               Student              0
# 5079         R05078      F     4               Student              0
# 10174        R10170      M     4  Working Professional              2
# 22349        R22343      M     4  Working Professional              4
# 304          R00305      F     1               Retired              1
# 7603         R07601      F     2               Retired              2
# 6892         R06890      M     4  Working Professional              4
# 24035        R24027      M     3  Working Professional              3
# 21917        R21911      F     4          Entrepreneur              3
# 29157        R29148      F     4  Working Professional              2
# 23155        R23148      F     4               Student              0
# 5930         R05928      F     3          Entrepreneur              5
# 14900        R14895      F     3               Student              0
# 1769         R01770      F     2  Working Professional              3
# 14490        R14485      F     2  Working Professional              3
#
#        consume_frequency(weekly) current_brand preferable_consumption_size  \
# 15031                          1   Established             Medium (500 ml)
# 20349                          1      Newcomer             Medium (500 ml)
# 9127                           2   Established              Small (250 ml)
# 29438                          2      Newcomer                 Large (1 L)
# 15594                          3      Newcomer                 Large (1 L)
# 27106                          3      Newcomer             Medium (500 ml)
# 22105                          2      Newcomer             Medium (500 ml)
# 21288                          2      Newcomer              Small (250 ml)
# 1417                           3      Newcomer              Small (250 ml)
# 8013                           2      Newcomer              Small (250 ml)
# 22676                          2      Newcomer             Medium (500 ml)
# 5079                           2      Newcomer              Small (250 ml)
# 10174                          1      Newcomer             Medium (500 ml)
# 22349                          3      Newcomer                 Large (1 L)
# 304                            2      Newcomer              Small (250 ml)
# 7603                           3   Established              Small (250 ml)
# 6892                           1   Established             Medium (500 ml)
# 24035                          1      Newcomer              Small (250 ml)
# 21917                          2      Newcomer                 Large (1 L)
# 29157                          1   Established              Small (250 ml)
# 23155                          1   Established             Medium (500 ml)
# 5930                           2      Newcomer                 Large (1 L)
# 14900                          1      Newcomer             Medium (500 ml)
# 1769                           3   Established             Medium (500 ml)
# 14490                          2      Newcomer              Small (250 ml)
#
#        awareness_of_other_brands reasons_for_choosing_brands  \
# 15031                          1                       Price
# 20349                          1                     Quality
# 9127                           3                     Quality
# 29438                          1                       Price
# 15594                          1                       Price
# 27106                          3                     Quality
# 22105                          1                       Price
# 21288                          1                       Price
# 1417                           1                       Price
# 8013                           1                       Price
# 22676                          1                       Price
# 5079                           2                       Price
# 10174                          1                Availability
# 22349                          2            Brand Reputation
# 304                            2                       Price
# 7603                           1                       Price
# 6892                           2                     Quality
# 24035                          2            Brand Reputation
# 21917                          2                Availability
# 29157                          2                       Price
# 23155                          1                       Price
# 5930                           2                Availability
# 14900                          2                       Price
# 1769                           1                     Quality
# 14490                          2                Availability
#
#       flavor_preference purchase_channel packaging_preference  \
# 15031       Traditional           Online               Simple
# 20349            Exotic           Online              Premium
# 9127             Exotic           Online         Eco-Friendly
# 29438            Exotic           Online         Eco-Friendly
# 15594            Exotic     Retail Store              Premium
# 27106            Exotic           Online               Simple
# 22105            Exotic     Retail Store              Premium
# 21288            Exotic     Retail Store              Premium
# 1417        Traditional           Online         Eco-Friendly
# 8013             Exotic     Retail Store               Simple
# 22676            Exotic           Online               Simple
# 5079             Exotic     Retail Store               Simple
# 10174            Exotic           Online              Premium
# 22349       Traditional     Retail Store              Premium
# 304         Traditional           Online               Simple
# 7603        Traditional     Retail Store               Simple
# 6892             Exotic           Online              Premium
# 24035       Traditional           Online              Premium
# 21917       Traditional           Online              Premium
# 29157       Traditional     Retail Store              Premium
# 23155            Exotic           Online              Premium
# 5930             Exotic     Retail Store         Eco-Friendly
# 14900            Exotic           Online               Simple
# 1769        Traditional           Online              Premium
# 14490       Traditional     Retail Store         Eco-Friendly
#
#                             health_concerns typical_consumption_situations  \
# 15031          High (Very health-conscious)       Active (eg. Sports, gym)
# 20349  Medium (Moderately health-conscious)           Casual (eg. At home)
# 9127           High (Very health-conscious)       Active (eg. Sports, gym)
# 29438  Medium (Moderately health-conscious)       Active (eg. Sports, gym)
# 15594  Medium (Moderately health-conscious)       Active (eg. Sports, gym)
# 27106              Low (Not very concerned)           Casual (eg. At home)
# 22105  Medium (Moderately health-conscious)           Social (eg. Parties)
# 21288  Medium (Moderately health-conscious)           Casual (eg. At home)
# 1417               Low (Not very concerned)           Casual (eg. At home)
# 8013           High (Very health-conscious)       Active (eg. Sports, gym)
# 22676          High (Very health-conscious)       Active (eg. Sports, gym)
# 5079   Medium (Moderately health-conscious)       Active (eg. Sports, gym)
# 10174  Medium (Moderately health-conscious)       Active (eg. Sports, gym)
# 22349              Low (Not very concerned)       Active (eg. Sports, gym)
# 304    Medium (Moderately health-conscious)           Casual (eg. At home)
# 7603           High (Very health-conscious)       Active (eg. Sports, gym)
# 6892           High (Very health-conscious)           Casual (eg. At home)
# 24035  Medium (Moderately health-conscious)       Active (eg. Sports, gym)
# 21917  Medium (Moderately health-conscious)           Casual (eg. At home)
# 29157              Low (Not very concerned)           Social (eg. Parties)
# 23155          High (Very health-conscious)       Active (eg. Sports, gym)
# 5930           High (Very health-conscious)       Active (eg. Sports, gym)
# 14900              Low (Not very concerned)       Active (eg. Sports, gym)
# 1769           High (Very health-conscious)           Casual (eg. At home)
# 14490  Medium (Moderately health-conscious)       Active (eg. Sports, gym)
#
#       price_range age_group  cf_ab_score  zas_score  bsi
# 15031      50-100     18-25         0.50          0    0
# 20349     150-200     36-45         0.50          9    1
# 9127      200-250     26-35         0.40          8    0
# 29438     100-150     26-35         0.67          3    1
# 15594     150-200     26-35         0.75          3    1
# 27106     200-250     26-35         0.50         20    1
# 22105     100-150     26-35         0.67          2    1
# 21288      50-100     18-25         0.67          0    1
# 1417      100-150     26-35         0.75          4    1
# 8013      150-200     26-35         0.67          6    1
# 22676     100-150     18-25         0.67          0    1
# 5079      100-150     26-35         0.50          0    1
# 10174     100-150     18-25         0.50          8    0
# 22349     200-250     26-35         0.60         16    0
# 304       100-150     56-70         0.50          1    1
# 7603      100-150     56-70         0.75          4    0
# 6892      200-250     36-45         0.33         16    0
# 24035     150-200     26-35         0.33          9    0
# 21917     150-200     36-45         0.50         12    0
# 29157     100-150     26-35         0.33          8    0
# 23155     100-150     18-25         0.50          0    0
# 5930      200-250     36-45         0.50         15    0
# 14900      50-100     18-25         0.33          0    1
# 1769      200-250     36-45         0.75          6    0
# 14490     100-150     26-35         0.50          6    0

# %%
df['current_brand'].dtype, df['reasons_for_choosing_brands'].dtype
# Out:
# (dtype('O'), dtype('O'))

# %%
df['current_brand'].isna().sum(), df['reasons_for_choosing_brands'].isna().sum()
# Out:
# (np.int64(0), np.int64(0))

# %%
df['bsi'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Final Cleaning Step:
# #### Removing Logical Outliers:

# %%
df.head()
# Out:
#   respondent_id gender  zone            occupation  income_levels  \
# 0        R00001      M     3  Working Professional              1
# 1        R00002      F     4  Working Professional              5
# 2        R00003      F     1  Working Professional              5
# 3        R00004      F     3  Working Professional              3
# 4        R00005      M     4               Student              0
#
#    consume_frequency(weekly) current_brand preferable_consumption_size  \
# 0                          2      Newcomer             Medium (500 ml)
# 1                          3   Established             Medium (500 ml)
# 2                          2      Newcomer             Medium (500 ml)
# 3                          3      Newcomer             Medium (500 ml)
# 4                          2   Established             Medium (500 ml)
#
#    awareness_of_other_brands reasons_for_choosing_brands flavor_preference  \
# 0                          1                       Price       Traditional
# 1                          2                     Quality            Exotic
# 2                          2                Availability       Traditional
# 3                          1            Brand Reputation            Exotic
# 4                          1                Availability       Traditional
#
#   purchase_channel packaging_preference                       health_concerns  \
# 0           Online               Simple  Medium (Moderately health-conscious)
# 1     Retail Store              Premium  Medium (Moderately health-conscious)
# 2     Retail Store              Premium  Medium (Moderately health-conscious)
# 3           Online         Eco-Friendly              Low (Not very concerned)
# 4           Online              Premium  Medium (Moderately health-conscious)
#
#   typical_consumption_situations price_range age_group  cf_ab_score  \
# 0       Active (eg. Sports, gym)     100-150     26-35         0.67
# 1           Social (eg. Parties)     200-250     46-55         0.60
# 2       Active (eg. Sports, gym)     200-250     36-45         0.50
# 3       Active (eg. Sports, gym)     150-200     26-35         0.75
# 4       Active (eg. Sports, gym)      50-100     18-25         0.67
#
#    zas_score  bsi
# 0          3    1
# 1         20    0
# 2          5    0
# 3          9    0
# 4          0    0

# %%
df.groupby('age_group')['occupation'].value_counts()
# Out:
# age_group  occupation
# 18-25      Student                 7328
#            Working Professional    2605
#            Entrepreneur             535
# 26-35      Working Professional    6570
#            Entrepreneur            1826
#            Student                  697
# 36-45      Working Professional    4353
#            Entrepreneur            1619
# 46-55      Working Professional    2167
#            Entrepreneur             799
# 56-70      Retired                 1130
#            Entrepreneur             221
#            Working Professional     106
#            Student                   35
# Name: count, dtype: int64

# %%
df[(df['age_group'] == '18-25') & (df['occupation']=='Entrepreneur')]
# Out:
#       respondent_id gender  zone    occupation  income_levels  \
# 25           R00026      F     4  Entrepreneur              4
# 58           R00059      F     3  Entrepreneur              3
# 81           R00082      M     4  Entrepreneur              2
# 113          R00114      F     3  Entrepreneur              3
# 159          R00160      M     1  Entrepreneur              2
# ...             ...    ...   ...           ...            ...
# 29777        R29768      M     3  Entrepreneur              2
# 29852        R29843      M     2  Entrepreneur              3
# 29894        R29885      F     3  Entrepreneur              3
# 29968        R29959      M     4  Entrepreneur              1
# 29994        R29985      F     3  Entrepreneur              2
#
#        consume_frequency(weekly) current_brand preferable_consumption_size  \
# 25                             3   Established                 Large (1 L)
# 58                             2   Established             Medium (500 ml)
# 81                             2   Established             Medium (500 ml)
# 113                            3   Established             Medium (500 ml)
# 159                            1      Newcomer              Small (250 ml)
# ...                          ...           ...                         ...
# 29777                          1      Newcomer             Medium (500 ml)
# 29852                          3   Established             Medium (500 ml)
# 29894                          3      Newcomer             Medium (500 ml)
# 29968                          1   Established              Small (250 ml)
# 29994                          2      Newcomer                 Large (1 L)
#
#        awareness_of_other_brands reasons_for_choosing_brands  \
# 25                             3                     Quality
# 58                             1                     Quality
# 81                             3                       Price
# 113                            3                     Quality
# 159                            3                       Price
# ...                          ...                         ...
# 29777                          1                       Price
# 29852                          1            Brand Reputation
# 29894                          2            Brand Reputation
# 29968                          1                       Price
# 29994                          2                       Price
#
#       flavor_preference purchase_channel packaging_preference  \
# 25               Exotic           Online              Premium
# 58          Traditional           Online         Eco-Friendly
# 81          Traditional     Retail Store              Premium
# 113         Traditional     Retail Store              Premium
# 159         Traditional           Online               Simple
# ...                 ...              ...                  ...
# 29777            Exotic           Online               Simple
# 29852       Traditional     Retail Store         Eco-Friendly
# 29894       Traditional           Online               Simple
# 29968       Traditional     Retail Store               Simple
# 29994       Traditional           Online              Premium
#
#                             health_concerns typical_consumption_situations  \
# 25     Medium (Moderately health-conscious)           Social (eg. Parties)
# 58                 Low (Not very concerned)           Social (eg. Parties)
# 81             High (Very health-conscious)       Active (eg. Sports, gym)
# 113                Low (Not very concerned)       Active (eg. Sports, gym)
# 159                Low (Not very concerned)           Casual (eg. At home)
# ...                                     ...                            ...
# 29777  Medium (Moderately health-conscious)           Social (eg. Parties)
# 29852  Medium (Moderately health-conscious)       Active (eg. Sports, gym)
# 29894  Medium (Moderately health-conscious)           Casual (eg. At home)
# 29968          High (Very health-conscious)           Casual (eg. At home)
# 29994              Low (Not very concerned)       Active (eg. Sports, gym)
#
#       price_range age_group  cf_ab_score  zas_score  bsi
# 25        200-250     18-25         0.50         16    0
# 58        150-200     18-25         0.67          9    0
# 81        200-250     18-25         0.40          8    0
# 113       200-250     18-25         0.50          9    0
# 159       100-150     18-25         0.25          2    1
# ...           ...       ...          ...        ...  ...
# 29777     100-150     18-25         0.50          6    1
# 29852     100-150     18-25         0.75          6    0
# 29894     200-250     18-25         0.60          9    0
# 29968     100-150     18-25         0.50          4    0
# 29994     150-200     18-25         0.50          6    1
#
# [535 rows x 20 columns]

# %%
df = df[~((df['age_group'] == '56-70') & (df['occupation']=='Student'))]
print(df.shape)
df.head()
# Out:
# (29956, 20)
#   respondent_id gender  zone            occupation  income_levels  \
# 0        R00001      M     3  Working Professional              1
# 1        R00002      F     4  Working Professional              5
# 2        R00003      F     1  Working Professional              5
# 3        R00004      F     3  Working Professional              3
# 4        R00005      M     4               Student              0
#
#    consume_frequency(weekly) current_brand preferable_consumption_size  \
# 0                          2      Newcomer             Medium (500 ml)
# 1                          3   Established             Medium (500 ml)
# 2                          2      Newcomer             Medium (500 ml)
# 3                          3      Newcomer             Medium (500 ml)
# 4                          2   Established             Medium (500 ml)
#
#    awareness_of_other_brands reasons_for_choosing_brands flavor_preference  \
# 0                          1                       Price       Traditional
# 1                          2                     Quality            Exotic
# 2                          2                Availability       Traditional
# 3                          1            Brand Reputation            Exotic
# 4                          1                Availability       Traditional
#
#   purchase_channel packaging_preference                       health_concerns  \
# 0           Online               Simple  Medium (Moderately health-conscious)
# 1     Retail Store              Premium  Medium (Moderately health-conscious)
# 2     Retail Store              Premium  Medium (Moderately health-conscious)
# 3           Online         Eco-Friendly              Low (Not very concerned)
# 4           Online              Premium  Medium (Moderately health-conscious)
#
#   typical_consumption_situations price_range age_group  cf_ab_score  \
# 0       Active (eg. Sports, gym)     100-150     26-35         0.67
# 1           Social (eg. Parties)     200-250     46-55         0.60
# 2       Active (eg. Sports, gym)     200-250     36-45         0.50
# 3       Active (eg. Sports, gym)     150-200     26-35         0.75
# 4       Active (eg. Sports, gym)      50-100     18-25         0.67
#
#    zas_score  bsi
# 0          3    1
# 1         20    0
# 2          5    0
# 3          9    0
# 4          0    0

# %%
df.groupby('age_group')['occupation'].value_counts()
# Out:
# age_group  occupation
# 18-25      Student                 7328
#            Working Professional    2605
#            Entrepreneur             535
# 26-35      Working Professional    6570
#            Entrepreneur            1826
#            Student                  697
# 36-45      Working Professional    4353
#            Entrepreneur            1619
# 46-55      Working Professional    2167
#            Entrepreneur             799
# 56-70      Retired                 1130
#            Entrepreneur             221
#            Working Professional     106
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (29956, 20)

# %%
df['bsi'].value_counts()
# Out:
# bsi
# 0    20796
# 1     9160
# Name: count, dtype: int64

# %% [markdown]
# <h2 align = 'center'>Working with modeling<h2>

# %% [markdown]
# ### 1 / Prepare feature and target variables

# %%
df.head()
# Out:
#   respondent_id gender  zone            occupation  income_levels  \
# 0        R00001      M     3  Working Professional              1
# 1        R00002      F     4  Working Professional              5
# 2        R00003      F     1  Working Professional              5
# 3        R00004      F     3  Working Professional              3
# 4        R00005      M     4               Student              0
#
#    consume_frequency(weekly) current_brand preferable_consumption_size  \
# 0                          2      Newcomer             Medium (500 ml)
# 1                          3   Established             Medium (500 ml)
# 2                          2      Newcomer             Medium (500 ml)
# 3                          3      Newcomer             Medium (500 ml)
# 4                          2   Established             Medium (500 ml)
#
#    awareness_of_other_brands reasons_for_choosing_brands flavor_preference  \
# 0                          1                       Price       Traditional
# 1                          2                     Quality            Exotic
# 2                          2                Availability       Traditional
# 3                          1            Brand Reputation            Exotic
# 4                          1                Availability       Traditional
#
#   purchase_channel packaging_preference                       health_concerns  \
# 0           Online               Simple  Medium (Moderately health-conscious)
# 1     Retail Store              Premium  Medium (Moderately health-conscious)
# 2     Retail Store              Premium  Medium (Moderately health-conscious)
# 3           Online         Eco-Friendly              Low (Not very concerned)
# 4           Online              Premium  Medium (Moderately health-conscious)
#
#   typical_consumption_situations price_range age_group  cf_ab_score  \
# 0       Active (eg. Sports, gym)     100-150     26-35         0.67
# 1           Social (eg. Parties)     200-250     46-55         0.60
# 2       Active (eg. Sports, gym)     200-250     36-45         0.50
# 3       Active (eg. Sports, gym)     150-200     26-35         0.75
# 4       Active (eg. Sports, gym)      50-100     18-25         0.67
#
#    zas_score  bsi
# 0          3    1
# 1         20    0
# 2          5    0
# 3          9    0
# 4          0    0

# %%
X = df.drop(['respondent_id','price_range'], axis=1)
y = df['price_range']

# %%
print(X.shape)
X.head()
# Out:
# (29956, 18)
#   gender  zone            occupation  income_levels  \
# 0      M     3  Working Professional              1
# 1      F     4  Working Professional              5
# 2      F     1  Working Professional              5
# 3      F     3  Working Professional              3
# 4      M     4               Student              0
#
#    consume_frequency(weekly) current_brand preferable_consumption_size  \
# 0                          2      Newcomer             Medium (500 ml)
# 1                          3   Established             Medium (500 ml)
# 2                          2      Newcomer             Medium (500 ml)
# 3                          3      Newcomer             Medium (500 ml)
# 4                          2   Established             Medium (500 ml)
#
#    awareness_of_other_brands reasons_for_choosing_brands flavor_preference  \
# 0                          1                       Price       Traditional
# 1                          2                     Quality            Exotic
# 2                          2                Availability       Traditional
# 3                          1            Brand Reputation            Exotic
# 4                          1                Availability       Traditional
#
#   purchase_channel packaging_preference                       health_concerns  \
# 0           Online               Simple  Medium (Moderately health-conscious)
# 1     Retail Store              Premium  Medium (Moderately health-conscious)
# 2     Retail Store              Premium  Medium (Moderately health-conscious)
# 3           Online         Eco-Friendly              Low (Not very concerned)
# 4           Online              Premium  Medium (Moderately health-conscious)
#
#   typical_consumption_situations age_group  cf_ab_score  zas_score  bsi
# 0       Active (eg. Sports, gym)     26-35         0.67          3    1
# 1           Social (eg. Parties)     46-55         0.60         20    0
# 2       Active (eg. Sports, gym)     36-45         0.50          5    0
# 3       Active (eg. Sports, gym)     26-35         0.75          9    0
# 4       Active (eg. Sports, gym)     18-25         0.67          0    0

# %%
y = y.map({'50-100':1,'100-150':2,'150-200':3,'200-250':4})

# %%
y.shape
# Out:
# (29956,)

# %% [markdown]
# ### 2 / Data split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
X.columns
# Out:
# Index(['gender', 'zone', 'occupation', 'income_levels',
#        'consume_frequency(weekly)', 'current_brand',
#        'preferable_consumption_size', 'awareness_of_other_brands',
#        'reasons_for_choosing_brands', 'flavor_preference', 'purchase_channel',
#        'packaging_preference', 'health_concerns',
#        'typical_consumption_situations', 'age_group', 'cf_ab_score',
#        'zas_score', 'bsi'],
#       dtype='object')

# %%
feature_list = ['age_group','income_levels','consume_frequency(weekly)','health_concerns','preferable_consumption_size']

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
for feature in feature_list:
    X_train[feature] = encoder.fit_transform(X_train[feature])
    X_test[feature] = encoder.transform(X_test[feature])

# %%
X_train.head()
# Out:
#       gender  zone            occupation  income_levels  \
# 8391       F     2  Working Professional              2
# 26395      F     3  Working Professional              3
# 11276      F     3               Student              0
# 9110       M     4  Working Professional              3
# 3373       M     4          Entrepreneur              3
#
#        consume_frequency(weekly) current_brand  preferable_consumption_size  \
# 8391                           0      Newcomer                            2
# 26395                          2   Established                            1
# 11276                          1      Newcomer                            2
# 9110                           1   Established                            0
# 3373                           0   Established                            0
#
#        awareness_of_other_brands reasons_for_choosing_brands  \
# 8391                           3                Availability
# 26395                          2                     Quality
# 11276                          2                       Price
# 9110                           2                     Quality
# 3373                           3            Brand Reputation
#
#       flavor_preference purchase_channel packaging_preference  \
# 8391        Traditional           Online               Simple
# 26395       Traditional           Online              Premium
# 11276       Traditional           Online               Simple
# 9110        Traditional           Online              Premium
# 3373        Traditional           Online         Eco-Friendly
#
#        health_concerns typical_consumption_situations  age_group  cf_ab_score  \
# 8391                 1           Social (eg. Parties)          0         0.25
# 26395                2           Social (eg. Parties)          0         0.60
# 11276                2       Active (eg. Sports, gym)          0         0.50
# 9110                 1       Active (eg. Sports, gym)          1         0.50
# 3373                 2           Casual (eg. At home)          1         0.25
#
#        zas_score  bsi
# 8391           4    0
# 26395          9    0
# 11276          0    1
# 9110          12    0
# 3373          12    0

# %%
X_test.head()
# Out:
#       gender  zone            occupation  income_levels  \
# 11981      M     3               Student              0
# 1805       M     4  Working Professional              2
# 517        M     4  Working Professional              3
# 3820       F     4  Working Professional              3
# 28625      M     4          Entrepreneur              4
#
#        consume_frequency(weekly) current_brand  preferable_consumption_size  \
# 11981                          2   Established                            0
# 1805                           0      Newcomer                            2
# 517                            0   Established                            1
# 3820                           2      Newcomer                            1
# 28625                          2      Newcomer                            1
#
#        awareness_of_other_brands reasons_for_choosing_brands  \
# 11981                          1                       Price
# 1805                           3                       Price
# 517                            3            Brand Reputation
# 3820                           2                     Quality
# 28625                          1                     Quality
#
#       flavor_preference purchase_channel packaging_preference  \
# 11981            Exotic           Online               Simple
# 1805             Exotic           Online               Simple
# 517              Exotic     Retail Store              Premium
# 3820        Traditional     Retail Store              Premium
# 28625            Exotic           Online              Premium
#
#        health_concerns typical_consumption_situations  age_group  cf_ab_score  \
# 11981                2           Social (eg. Parties)          0         0.75
# 1805                 0       Active (eg. Sports, gym)          0         0.25
# 517                  2       Active (eg. Sports, gym)          1         0.25
# 3820                 2       Active (eg. Sports, gym)          3         0.60
# 28625                0           Casual (eg. At home)          2         0.75
#
#        zas_score  bsi
# 11981          0    0
# 1805           8    1
# 517           12    0
# 3820          12    1
# 28625         16    1

# %%
X.select_dtypes('object').columns
# Out:
# Index(['gender', 'occupation', 'current_brand', 'preferable_consumption_size',
#        'reasons_for_choosing_brands', 'flavor_preference', 'purchase_channel',
#        'packaging_preference', 'health_concerns',
#        'typical_consumption_situations', 'age_group'],
#       dtype='object')

# %%
list_categories = ['gender', 'occupation', 'current_brand', 'reasons_for_choosing_brands',
       'flavor_preference', 'purchase_channel', 'packaging_preference',
       'typical_consumption_situations']

# %%
X_train = pd.get_dummies(data=X_train, columns=list_categories, drop_first=True, dtype='int')
X_train.head()
# Out:
#        zone  income_levels  consume_frequency(weekly)  \
# 8391      2              2                          0
# 26395     3              3                          2
# 11276     3              0                          1
# 9110      4              3                          1
# 3373      4              3                          0
#
#        preferable_consumption_size  awareness_of_other_brands  \
# 8391                             2                          3
# 26395                            1                          2
# 11276                            2                          2
# 9110                             0                          2
# 3373                             0                          3
#
#        health_concerns  age_group  cf_ab_score  zas_score  bsi  ...  \
# 8391                 1          0         0.25          4    0  ...
# 26395                2          0         0.60          9    0  ...
# 11276                2          0         0.50          0    1  ...
# 9110                 1          1         0.50         12    0  ...
# 3373                 2          1         0.25         12    0  ...
#
#        current_brand_Newcomer  reasons_for_choosing_brands_Brand Reputation  \
# 8391                        1                                             0
# 26395                       0                                             0
# 11276                       1                                             0
# 9110                        0                                             0
# 3373                        0                                             1
#
#        reasons_for_choosing_brands_Price  reasons_for_choosing_brands_Quality  \
# 8391                                   0                                    0
# 26395                                  0                                    1
# 11276                                  1                                    0
# 9110                                   0                                    1
# 3373                                   0                                    0
#
#        flavor_preference_Traditional  purchase_channel_Retail Store  \
# 8391                               1                              0
# 26395                              1                              0
# 11276                              1                              0
# 9110                               1                              0
# 3373                               1                              0
#
#        packaging_preference_Premium  packaging_preference_Simple  \
# 8391                              0                            1
# 26395                             1                            0
# 11276                             0                            1
# 9110                              1                            0
# 3373                              0                            0
#
#        typical_consumption_situations_Casual (eg. At home)  \
# 8391                                                   0
# 26395                                                  0
# 11276                                                  0
# 9110                                                   0
# 3373                                                   1
#
#        typical_consumption_situations_Social (eg. Parties)
# 8391                                                   1
# 26395                                                  1
# 11276                                                  0
# 9110                                                   0
# 3373                                                   0
#
# [5 rows x 24 columns]

# %%
X_test = pd.get_dummies(data=X_test, columns=list_categories, drop_first=True, dtype='int')
X_test.head()
# Out:
#        zone  income_levels  consume_frequency(weekly)  \
# 11981     3              0                          2
# 1805      4              2                          0
# 517       4              3                          0
# 3820      4              3                          2
# 28625     4              4                          2
#
#        preferable_consumption_size  awareness_of_other_brands  \
# 11981                            0                          1
# 1805                             2                          3
# 517                              1                          3
# 3820                             1                          2
# 28625                            1                          1
#
#        health_concerns  age_group  cf_ab_score  zas_score  bsi  ...  \
# 11981                2          0         0.75          0    0  ...
# 1805                 0          0         0.25          8    1  ...
# 517                  2          1         0.25         12    0  ...
# 3820                 2          3         0.60         12    1  ...
# 28625                0          2         0.75         16    1  ...
#
#        current_brand_Newcomer  reasons_for_choosing_brands_Brand Reputation  \
# 11981                       0                                             0
# 1805                        1                                             0
# 517                         0                                             1
# 3820                        1                                             0
# 28625                       1                                             0
#
#        reasons_for_choosing_brands_Price  reasons_for_choosing_brands_Quality  \
# 11981                                  1                                    0
# 1805                                   1                                    0
# 517                                    0                                    0
# 3820                                   0                                    1
# 28625                                  0                                    1
#
#        flavor_preference_Traditional  purchase_channel_Retail Store  \
# 11981                              0                              0
# 1805                               0                              0
# 517                                0                              1
# 3820                               1                              1
# 28625                              0                              0
#
#        packaging_preference_Premium  packaging_preference_Simple  \
# 11981                             0                            1
# 1805                              0                            1
# 517                               1                            0
# 3820                              1                            0
# 28625                             1                            0
#
#        typical_consumption_situations_Casual (eg. At home)  \
# 11981                                                  0
# 1805                                                   0
# 517                                                    0
# 3820                                                   0
# 28625                                                  1
#
#        typical_consumption_situations_Social (eg. Parties)
# 11981                                                  1
# 1805                                                   0
# 517                                                    0
# 3820                                                   0
# 28625                                                  0
#
# [5 rows x 24 columns]

# %%
X_train.head()
# Out:
#        zone  income_levels  consume_frequency(weekly)  \
# 8391      2              2                          0
# 26395     3              3                          2
# 11276     3              0                          1
# 9110      4              3                          1
# 3373      4              3                          0
#
#        preferable_consumption_size  awareness_of_other_brands  \
# 8391                             2                          3
# 26395                            1                          2
# 11276                            2                          2
# 9110                             0                          2
# 3373                             0                          3
#
#        health_concerns  age_group  cf_ab_score  zas_score  bsi  ...  \
# 8391                 1          0         0.25          4    0  ...
# 26395                2          0         0.60          9    0  ...
# 11276                2          0         0.50          0    1  ...
# 9110                 1          1         0.50         12    0  ...
# 3373                 2          1         0.25         12    0  ...
#
#        current_brand_Newcomer  reasons_for_choosing_brands_Brand Reputation  \
# 8391                        1                                             0
# 26395                       0                                             0
# 11276                       1                                             0
# 9110                        0                                             0
# 3373                        0                                             1
#
#        reasons_for_choosing_brands_Price  reasons_for_choosing_brands_Quality  \
# 8391                                   0                                    0
# 26395                                  0                                    1
# 11276                                  1                                    0
# 9110                                   0                                    1
# 3373                                   0                                    0
#
#        flavor_preference_Traditional  purchase_channel_Retail Store  \
# 8391                               1                              0
# 26395                              1                              0
# 11276                              1                              0
# 9110                               1                              0
# 3373                               1                              0
#
#        packaging_preference_Premium  packaging_preference_Simple  \
# 8391                              0                            1
# 26395                             1                            0
# 11276                             0                            1
# 9110                              1                            0
# 3373                              0                            0
#
#        typical_consumption_situations_Casual (eg. At home)  \
# 8391                                                   0
# 26395                                                  0
# 11276                                                  0
# 9110                                                   0
# 3373                                                   1
#
#        typical_consumption_situations_Social (eg. Parties)
# 8391                                                   1
# 26395                                                  1
# 11276                                                  0
# 9110                                                   0
# 3373                                                   0
#
# [5 rows x 24 columns]

# %%
y_train.head()
# Out:
# 8391     1
# 26395    4
# 11276    2
# 9110     3
# 3373     3
# Name: price_range, dtype: int64

# %%
y_train.unique()
# Out:
# array([1, 4, 2, 3])

# %%
print(X_train.shape), print(y_train.shape), print(X_test.shape), print(y_test.shape)
# Out:
# (22467, 24)
# (22467,)
# (7489, 24)
# (7489,)
# (None, None, None, None)

# %% [markdown]
# <h1 align = 'center'>Traning Model<h1>

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, LogisticRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVC
from xgboost import XGBRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Train with LinearRegression
model_lr = LinearRegression()
model_lr.fit(X_train, y_train)
y_pred_lr = model_lr.predict(X_test)
print(f"Mean squared error (LR): {mean_squared_error(y_test, y_pred_lr)}")
print(f"R2 score (LR): {r2_score(y_test, y_pred_lr)}")
# Out:
# Mean squared error (LR): 0.17943987134761918
# R2 score (LR): 0.8266960098530075

# %%
# train with Lasso
model_lasso = Lasso()
model_lasso.fit(X_train, y_train)
y_pred_ls = model_lasso.predict(X_test)
print(f"mean squared error (Lasso): {mean_squared_error(y_test, y_pred_ls)}")
print(f"f2 score (Lasso): {r2_score(y_test, y_pred_ls)}")
# Out:
# mean squared error (Lasso): 0.45538540004915246
# f2 score (Lasso): 0.5601863382396499

# %%
#train with SVM
model_svm = SVC()
model_svm.fit(X_train,y_train)
y_pred_svc = model_svm.predict(X_test)
print(f"mean squared error (SVM): {mean_squared_error(y_test, y_pred_svc)}")
print(f" F2 score (SVM): {r2_score(y_test, y_pred_svc)}")
# Out:
# mean squared error (SVM): 0.1870743757511016
#  F2 score (SVM): 0.8193225645535783

# %%
#train with RandomForest
model_rdf = RandomForestRegressor()
model_rdf.fit(X_train,y_train)
y_pred_rdf = model_rdf.predict(X_test)
print(f"Mean squared error (RDF): {mean_squared_error(y_test, y_pred_rdf)}")
print(f"F2 score (RDF): {r2_score(y_test, y_pred_rdf)}")
# Out:
# Mean squared error (RDF): 0.06689405132706856
# F2 score (RDF): 0.935393366451873

# %%
# train with Gradient Boosting
model_gr = GradientBoostingRegressor()
model_gr.fit(X_train,y_train)
y_pred_gr = model_gr.predict(X_test)
print(f"Mean squared error : {mean_squared_error(y_test, y_pred_gr)}")
print(f"R2 score : {r2_score(y_test,y_pred_gr)}")
# Out:
# Mean squared error : 0.09864492306592171
# R2 score : 0.9047282042353395

# %%
#train with xgboost
model_xgb = XGBRegressor()
model_xgb.fit(X_train, y_train)
y_pred_xgb = model_xgb.predict(X_test)
print(f"Mean squared : {mean_squared_error(y_test, y_pred_xgb)}")
print(f"R2 Score : {r2_score(y_test, y_pred_xgb)}")
# Out:
# Mean squared : 0.07340738580515101
# R2 Score : 0.9291027784347534

# %%
X.head()
# Out:
#   gender  zone            occupation  income_levels  \
# 0      M     3  Working Professional              1
# 1      F     4  Working Professional              5
# 2      F     1  Working Professional              5
# 3      F     3  Working Professional              3
# 4      M     4               Student              0
#
#    consume_frequency(weekly) current_brand preferable_consumption_size  \
# 0                          2      Newcomer             Medium (500 ml)
# 1                          3   Established             Medium (500 ml)
# 2                          2      Newcomer             Medium (500 ml)
# 3                          3      Newcomer             Medium (500 ml)
# 4                          2   Established             Medium (500 ml)
#
#    awareness_of_other_brands reasons_for_choosing_brands flavor_preference  \
# 0                          1                       Price       Traditional
# 1                          2                     Quality            Exotic
# 2                          2                Availability       Traditional
# 3                          1            Brand Reputation            Exotic
# 4                          1                Availability       Traditional
#
#   purchase_channel packaging_preference                       health_concerns  \
# 0           Online               Simple  Medium (Moderately health-conscious)
# 1     Retail Store              Premium  Medium (Moderately health-conscious)
# 2     Retail Store              Premium  Medium (Moderately health-conscious)
# 3           Online         Eco-Friendly              Low (Not very concerned)
# 4           Online              Premium  Medium (Moderately health-conscious)
#
#   typical_consumption_situations age_group  cf_ab_score  zas_score  bsi
# 0       Active (eg. Sports, gym)     26-35         0.67          3    1
# 1           Social (eg. Parties)     46-55         0.60         20    0
# 2       Active (eg. Sports, gym)     36-45         0.50          5    0
# 3       Active (eg. Sports, gym)     26-35         0.75          9    0
# 4       Active (eg. Sports, gym)     18-25         0.67          0    0

# %%
y.unique()
# Out:
# array([2, 4, 3, 1])

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error, r2_score


# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=396)

# Preprocessing
numerical_features = X.select_dtypes(include=['int64', 'float64']).columns
categorical_features = X.select_dtypes(include=['object']).columns

preprocessor = ColumnTransformer(
    transformers=[
        ('num', MinMaxScaler(), numerical_features),
        ('cat', OneHotEncoder(drop='first'), categorical_features)
    ]
)

# Models
models = {
    "Linear Regression": LinearRegression(),
    "Logistic" : LogisticRegression(max_iter=1000),
    "GaussianNB" : GaussianNB(),
    "SVM": SVC(),
    "Random Forest": RandomForestRegressor(),
    "Gradient Boosting": GradientBoostingRegressor(),
    "XGBoost": XGBRegressor()
}

# Pipelines & Training
for name, model in models.items():
    pipeline = Pipeline(steps=[('preprocessor', preprocessor), ('model', model)])
    pipeline.fit(X_train, y_train)
    y_pred = pipeline.predict(X_test)
    mse = mean_squared_error(y_test, y_pred),
    r2  = r2_score(y_test, y_pred)
    print(f"{name} - Mean squared error: {mse}")
    print(f"{name} - R2 score: {r2}")
    print("*"*50)
# Out:
# Linear Regression - Mean squared error: (np.float64(0.1473624126259121),)
# Linear Regression - R2 score: 0.8618305750086444
# **************************************************
# Logistic - Mean squared error: (np.float64(0.15537383177570094),)
# Logistic - R2 score: 0.8543189364736465
# **************************************************
# GaussianNB - Mean squared error: (np.float64(0.5936248331108144),)
# GaussianNB - R2 score: 0.4434075800609675
# **************************************************
# SVM - Mean squared error: (np.float64(0.12750333778371162),)
# SVM - R2 score: 0.8804507706400279
# **************************************************
# Random Forest - Mean squared error: (np.float64(0.06968655993646762),)
# Random Forest - R2 score: 0.9346607337347957
# **************************************************
# Gradient Boosting - Mean squared error: (np.float64(0.10082203628707526),)
# Gradient Boosting - R2 score: 0.9054675983379411
# **************************************************
# XGBoost - Mean squared error: (np.float64(0.07084917210778409),)
# XGBoost - R2 score: 0.9335706233978271
# **************************************************

# %%
max_random_state = [396,392]

# %%
score = []
for i in range(1000):
    model_xg = LinearRegression()
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=i)
    pipeline = Pipeline(steps=[('preprocessor', preprocessor), ('model', model_xg)])
    pipeline.fit(X_train, y_train)
    y_pred = pipeline.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    r2  = r2_score(y_test, y_pred)
    score.append(r2)
np.argmax(score)
# Out:
# np.int64(392)

# %%
import mlflow
import mlflow.sklearn
from sklearn.metrics import mean_squared_error, r2_score

mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("ml_flow_internship_project")

numerical_features = X.select_dtypes(include=['int64', 'float64']).columns
categorical_features = X.select_dtypes(include=['object']).columns

# Dictionary to store results for comparison
results = []

# Start the main MLflow run
with mlflow.start_run(run_name="Main_Run"):
    # Preprocessing pipeline
    preprocessor = ColumnTransformer(
        transformers=[
            ('num', MinMaxScaler(), numerical_features),
            ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
        ]
    )

    # Define models
    models = {
        "Linear Regression": LinearRegression(),
        "Logistic Regression": LogisticRegression(max_iter=1000),
        "GaussianNB": GaussianNB(),
        "SVM": SVC(),
        "Random Forest": RandomForestRegressor(),
        "Gradient Boosting": GradientBoostingRegressor(),
        "XGBoost": XGBRegressor()
    }

    # Train and log each model
    for model_name, model in models.items():
        with mlflow.start_run(nested=True, run_name=model_name):  # Start a nested run
            pipeline = Pipeline(steps=[('preprocessor', preprocessor), ('model', model)])
            pipeline.fit(X_train, y_train)
            y_pred = pipeline.predict(X_test)

            # Calculate metrics
            mse = mean_squared_error(y_test, y_pred)
            r2 = r2_score(y_test, y_pred)

            # Log parameters, metrics, and the model
            mlflow.log_param("model_name", model_name)
            mlflow.log_metric("mean_squared_error", mse)
            mlflow.log_metric("r2_score", r2)
            mlflow.sklearn.log_model(pipeline, artifact_path=f"{model_name}_model")

            # Save results for chart comparison
            results.append({"Model": model_name, "Mean Squared Error": mse, "R2 Score": r2})

# Create a comparison chart
results_df = pd.DataFrame(results)
print(results_df)

# Optional: Save the results for offline use or visualization
results_df.to_csv("model_comparison.csv", index=False)

mlflow.end_run()
# Out:
# 2024/12/26 15:08:41 INFO mlflow.tracking.fluent: Experiment with name 'ml_flow_internship_project' does not exist. Creating a new experiment.
# 2024/12/26 15:08:46 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run Linear Regression at: http://127.0.0.1:5000/#/experiments/954989667127244111/runs/5fd5cb577795440daf6b7f663be60ffc
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/954989667127244111
# 2024/12/26 15:08:51 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run Logistic Regression at: http://127.0.0.1:5000/#/experiments/954989667127244111/runs/08fa070ab064417caf730b28d70644b4
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/954989667127244111
# 2024/12/26 15:08:55 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run GaussianNB at: http://127.0.0.1:5000/#/experiments/954989667127244111/runs/e3f37ee1316c419a945b4ea10deea105
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/954989667127244111
# 2024/12/26 15:09:28 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run SVM at: http://127.0.0.1:5000/#/experiments/954989667127244111/runs/81b8da5cd49a4d38abcbd602b7cd9c5d
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/954989667127244111
# 2024/12/26 15:09:40 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run Random Forest at: http://127.0.0.1:5000/#/experiments/954989667127244111/runs/b209a2b133554010ad4db527f402958c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/954989667127244111
# 2024/12/26 15:09:48 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run Gradient Boosting at: http://127.0.0.1:5000/#/experiments/954989667127244111/runs/85fc37399e9844b3ba1d5d7cdab6ab1c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/954989667127244111
# 2024/12/26 15:09:53 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run XGBoost at: http://127.0.0.1:5000/#/experiments/954989667127244111/runs/17accd2309a04da18ea4c4037e627150
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/954989667127244111
# 🏃 View run Main_Run at: http://127.0.0.1:5000/#/experiments/954989667127244111/runs/896c77d1735b404eb3c1c1271337553f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/954989667127244111
#                  Model  Mean Squared Error  R2 Score
# 0    Linear Regression            0.147527  0.861676
# 1  Logistic Regression            0.155040  0.854632
# 2           GaussianNB            0.531375  0.501774
# 3                  SVM            0.136515  0.872001
# 4        Random Forest            0.062504  0.941396
# 5    Gradient Boosting            0.096982  0.909068
# 6              XGBoost            0.071390  0.933063

# %%
# import mlflow
# import mlflow.sklearn
# from sklearn.metrics import mean_squared_error, r2_score
#
# mlflow.set_tracking_uri("http://127.0.0.1:5000")
# mlflow.set_experiment("export_model_2")
#
# models = {
#     "Linear Regression": LinearRegression(),
#     "Logistic" : LogisticRegression(),
#     "GaussianNB" : GaussianNB(),
#     "SVM": SVC(),
#     "Random Forest": RandomForestRegressor(),
#     "Gradient Boosting": GradientBoostingRegressor(),
#     "XGBoost": XGBRegressor()
# }
#
# for model_name, model in models.items():
#     with mlflow.start_run(run_name=model_name):
#         pipeline = Pipeline(steps=[('preprocessor', preprocessor), ('model', model)])
#         pipeline.fit(X_train, y_train)
#         y_pred = pipeline.predict(X_test)
#         mse = mean_squared_error(y_test, y_pred),
#         r2  = r2_score(y_test, y_pred)
#
#         # Log parameters, metrics, and model
#         mlflow.log_param("model_type", model_name)
#         mlflow.log_metric("mean_squared_error", mse)
#         mlflow.log_metric("r2_score", r2)
#         mlflow.sklearn.log_model(model, f"{model_name.lower()}_model")
#
#         print(f"Model {model_name}, metrics, and parameters logged to MLflow.")
# Out:
# 2024/12/26 14:43:14 INFO mlflow.tracking.fluent: Experiment with name 'export_model_2' does not exist. Creating a new experiment.
# 🏃 View run Linear Regression at: http://127.0.0.1:5000/#/experiments/341177682451086436/runs/48c6ab12b3284024a59516953bd1f2d6
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/341177682451086436
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[317], line 28
#      26 # Log parameters, metrics, and model
#      27 mlflow.log_param("model_type", model_name)
# ---> 28 mlflow.log_metric("mean_squared_error", mse)
#      29 mlflow.log_metric("r2_score", r2)
#      30 mlflow.sklearn.log_model(model, f"{model_name.lower()}_model")
#
# File /opt/anaconda3/lib/python3.11/site-packages/mlflow/tracking/fluent.py:923, in log_metric(key, value, step, synchronous, timestamp, run_id)
#     921 run_id = run_id or _get_or_start_run().info.run_id
#     922 synchronous = synchronous if synchronous is not None else not MLFLOW_ENABLE_ASYNC_LOGGING.get()
# --> 923 return MlflowClient().log_metric(
#     924     run_id,
#     925     key,
#     926     value,
#     927     timestamp or get_current_time_millis(),
#     928     step or 0,
#     929     synchronous=synchronous,
#     930 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/mlflow/tracking/client.py:1526, in MlflowClient.log_metric(self, run_id, key, value, timestamp, step, synchronous)
#    1453 """
#    1454 Log a metric against the run ID.
#    1455
#    (...)
#    1521     status: FINISHED
#    1522 """
#    1523 synchronous = (
#    1524     synchronous if synchronous is not None else not MLFLOW_ENABLE_ASYNC_LOGGING.get()
#    1525 )
# -> 1526 return self._tracking_client.log_metric(
#    1527     run_id, key, value, timestamp, step, synchronous=synchronous
#    1528 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py:580, in TrackingServiceClient.log_metric(self, run_id, key, value, timestamp, step, synchronous)
#     578 timestamp = timestamp if timestamp is not None else get_current_time_millis()
#     579 step = step if step is not None else 0
# --> 580 metric_value = convert_metric_value_to_float_if_possible(value)
#     581 metric = Metric(key, metric_value, timestamp, step)
#     582 if synchronous:
#
# File /opt/anaconda3/lib/python3.11/site-packages/mlflow/tracking/metric_value_conversion_utils.py:53, in convert_metric_value_to_float_if_possible(x)
#      50         return possible_float
#      52 try:
# ---> 53     return float(x)
#      54 except ValueError:
#      55     return x
#
# TypeError: float() argument must be a string or a real number, not 'tuple'
